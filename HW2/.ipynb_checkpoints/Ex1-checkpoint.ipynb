# %% [markdown]
# # Trung Nguyen - 111752939
# ## Assignment #2: Exploratory Data Analysis in IPython

# %% [markdown]
# ## Task 1

# %%
# df.columns
# df.dtypes
# df['bedroomcnt'].tolist()
# df.set_index('bathroomcnt')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import f_regression

df = pd.read_csv('./data/properties_2016.csv', low_memory=False)
# Calculate mean value and replace NaN values with mean value

# %%
df_filled = df.fillna(0)

# %%
corr = df_filled.corr(method='pearson', min_periods=1)
corr.head()
# Out:
#                           parcelid  airconditioningtypeid  \
# parcelid                  1.000000              -0.009222
# airconditioningtypeid    -0.009222               1.000000
# architecturalstyletypeid  0.006181               0.028683
# basementsqft              0.009950              -0.005086
# bathroomcnt              -0.106233               0.096380
#
#                           architecturalstyletypeid  basementsqft  bathroomcnt  \
# parcelid                                  0.006181      0.009950    -0.106233
# airconditioningtypeid                     0.028683     -0.005086     0.096380
# architecturalstyletypeid                  1.000000     -0.000767    -0.011601
# basementsqft                             -0.000767      1.000000     0.015224
# bathroomcnt                              -0.011601      0.015224     1.000000
#
#                           bedroomcnt  buildingclasstypeid  \
# parcelid                   -0.119294            -0.010975
# airconditioningtypeid       0.056700             0.034368
# architecturalstyletypeid   -0.021839            -0.002760
# basementsqft                0.008614            -0.001159
# bathroomcnt                 0.706488            -0.130900
#
#                           buildingqualitytypeid  calculatedbathnbr  \
# parcelid                              -0.208515          -0.106422
# airconditioningtypeid                 -0.136549           0.095586
# architecturalstyletypeid              -0.051402          -0.011585
# basementsqft                          -0.021609           0.015230
# bathroomcnt                           -0.040117           0.999096
#
#                           decktypeid         ...           yardbuildingsqft26  \
# parcelid                    0.038009         ...                     0.008652
# airconditioningtypeid      -0.021503         ...                    -0.005075
# architecturalstyletypeid   -0.003242         ...                    -0.000765
# basementsqft                0.115635         ...                     0.053763
# bathroomcnt                 0.041452         ...                     0.003123
#
#                           yearbuilt  numberofstories  \
# parcelid                  -0.337537         0.114261
# airconditioningtypeid      0.051116         0.236223
# architecturalstyletypeid   0.007433         0.084117
# basementsqft               0.001520         0.031402
# bathroomcnt                0.292480         0.029635
#
#                           structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# parcelid                                   -0.019238          -0.025607
# airconditioningtypeid                       0.045776           0.043263
# architecturalstyletypeid                   -0.007963          -0.007981
# basementsqft                                0.014693           0.014864
# bathroomcnt                                 0.277758           0.332508
#
#                           assessmentyear  landtaxvaluedollarcnt  taxamount  \
# parcelid                       -0.735218              -0.024538  -0.031959
# airconditioningtypeid           0.017573               0.029462   0.035854
# architecturalstyletypeid        0.002650              -0.005869  -0.009136
# basementsqft                    0.001113               0.011057   0.011107
# bathroomcnt                     0.125876               0.293366   0.316751
#
#                           taxdelinquencyyear  censustractandblock
# parcelid                           -0.018247            -0.307825
# airconditioningtypeid              -0.010682             0.017272
# architecturalstyletypeid           -0.003298             0.007077
# basementsqft                       -0.001938             0.003312
# bathroomcnt                        -0.018547             0.263374
#
# [5 rows x 53 columns]

# %%
corr_min = corr.min(axis=0)
corr_min = corr_min.min()

most_negative1 = 'parcelid'
most_negative2 = 'parcelid'
for index1 ,row in corr.iterrows():
    for index2, cell in row.iteritems():
        if cell == corr_min:
            most_negative1 = index1
            most_negative2 = index2
            break
print('The most negative correlation: %s - %s') %(most_negative1, most_negative2)
            
max_value=-2
max_x=None
max_y=None
for index1, row in corr.iterrows():
    for index2, item in row.iteritems():
        if index1==index2:
            continue
        if item>max_value:
            max_value=item
            max_x=index1
            max_y=index2

print('The most positive correlation: %s - %s') %(max_x, max_y)
# Out:
# The most negative correlation: assessmentyear - longitude
# The most positive correlation: fips - rawcensustractandblock

# %%
fig1, ax1 = plt.subplots(figsize=(18,18))  
sns.heatmap(corr, square=True, ax=ax1, linewidths=0.1, annot=True)
plt.show()

# %% [markdown]
# ## Task 3

# %%
y = pd.read_csv('./data/train_2016_v2.csv')
y_dropped = y.drop_duplicates('parcelid')

# %%
df_dropped = df_filled.drop(["hashottuborspa", "propertycountylandusecode", "propertyzoningdesc", 
                        "fireplaceflag", "taxdelinquencyflag", "assessmentyear"], axis=1)
X = df_dropped[df_dropped['parcelid'].isin(y_dropped.loc[:,'parcelid'])]
X_learn = X.copy()

# %%
# Use all features 
X_learn1 = np.reshape(X_learn, (-1, 52))
y_learn = y_dropped['logerror']
y_learn = np.reshape(y_learn, (-1, 1))

X_train, X_test, y_train, y_test = train_test_split(X_learn1, y_learn, test_size=0.2, random_state=1)

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# The coefficients
print("Coefficients: %.9f" % regr.coef_[0][0])
# The mean squared error
print("Mean squared error: %.9f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.9f' % r2_score(y_test, y_pred))
# Out:
# /Users/trungnguyen/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# Coefficients: -0.000000000
# Mean squared error: 0.032068872
# Variance score: -0.001245657

# %%
F, pval = f_regression(X_learn, y_learn.ravel(), center=True)
print('The most significant feature (smallest p-value): %s' %X.columns.values[pval.argmin()])
# Out:
# The most significant feature (smallest p-value): longitude

# %% [markdown]
# ## Task 4

# %%
# Use only one feature
X_learn2 = X_learn['longitude']
X_learn2 = np.reshape(X_learn2, (-1, 1))

y_learn = y_dropped['logerror']
y_learn = np.reshape(y_learn, (-1, 1))

X_train, X_test, y_train, y_test = train_test_split(X_learn2, y_learn, test_size=0.2, random_state=42)

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# The coefficients
print("Coefficients: %.9f" % regr.coef_[0][0])
# The mean squared error
print("Mean squared error: %.9f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.9f' % r2_score(y_test, y_pred))

# Plot outputs
plt.scatter(X_test, y_test,  color='red')
plt.plot(X_test, y_pred, color='blue', linewidth=2)
plt.ylabel('Log error')
plt.xlabel('Longitude')

plt.show()
# Out:
# Coefficients: 0.000000002
# Mean squared error: 0.027705462
# Variance score: 0.000095063

# %%
# Fill 'longitude' NaN values with its meadian instead of 0
longitude_median = df['longitude'].median(skipna=True)
X_notfilled = df[df['parcelid'].isin(y_dropped.loc[:,'parcelid'])]
X_notfilled.fillna(value=longitude_median, inplace=True)
X_learn2 = X_notfilled['longitude'].copy()
X_learn2 = np.reshape(X_learn2, (-1, 1))

y_learn = y_dropped['logerror']
y_learn = np.reshape(y_learn, (-1, 1))

X_train, X_test, y_train, y_test = train_test_split(X_learn2, y_learn, test_size=0.2, random_state=42)

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# The coefficients
print("Coefficients: %.9f" % regr.coef_[0][0])
# The mean squared error
print("Mean squared error: %.9f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.9f' % r2_score(y_test, y_pred))

# Plot outputs
plt.scatter(X_test, y_test,  color='red')
plt.plot(X_test, y_pred, color='blue', linewidth=2)
plt.ylabel('Log error')
plt.xlabel('Longitude')

plt.show()
# Out:
# Coefficients: 0.000000002
# Mean squared error: 0.027705462
# Variance score: 0.000095063

# %% [markdown]
# # Task 5

# %%
# X_predict = np.reshape(df_dropped, (-1, 52))
X_predict = np.reshape(df_dropped['longitude'], (-1, 1))

y_pred = regr.predict(X_predict)
df1 = pd.read_csv('./data/sample_submission.csv', low_memory=False)
df2 = df1.copy()

# %%
y_pred = np.ndarray.flatten(y_pred)
df3 = pd.DataFrame({'Log error prediction': y_pred})
df2['201610'] = df3['Log error prediction']
df2['201611'] = df3['Log error prediction']
df2['201612'] = df3['Log error prediction']
df2['201710'] = df3['Log error prediction']
df2['201711'] = df3['Log error prediction']
df2['201712'] = df3['Log error prediction']
df2.to_csv('./data/out.csv',index=False)
